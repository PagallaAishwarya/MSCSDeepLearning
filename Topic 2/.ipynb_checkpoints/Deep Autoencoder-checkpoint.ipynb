# %% [markdown]
# This is a Notebook  with  Deep Autoencoder. Using input of 5500 dimensions and reducing it to 32.

# %%
import nltk
nltk.download('punkt')
import numpy as np
import pandas as pd
from keras.models import Model
from keras.layers import Input, Dense
from keras.datasets import boston_housing

input_img = Input(shape=(5500,))

encoded = Dense(128, activation='relu')(input_img)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(32, activation='relu')(encoded)

decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(5500, activation='sigmoid')(decoded)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aishw\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# introducing a file of 1096 dimensions and using glove of 50 dimensions

# %%
df = pd.read_csv("data_v2_1096.csv", encoding="utf8")
docs = []
#iterate over every row of the dataframe
for index,row in df.iterrows():
  docs.append(row["sent_text"])

fn = 'glove.6B.50d.txt'
f = open(fn, encoding="utf8")
embeddings_index = dict()
for line in f:
  values = line.split()
  word = values[0]
  coefs = np.asarray(values[1:], dtype='float32')
  embeddings_index[word] = coefs

x_train = np.zeros((index+1,5500));
sntidx = 0
for sent in docs:
  tok = nltk.word_tokenize(sent.lower())
  asent = np.zeros((110,50))
  wrds = 0
  for token in tok:
    if token in embeddings_index:
      asent[wrds] = embeddings_index[token]
      wrds += 1
      if wrds == 110:
        break
  #print asent
  x_train[sntidx] = asent.flatten()
  sntidx += 1
x_test = x_train[100:200]
print(x_train.shape)
print(x_test.shape)
# Out:
# (1096, 5500)
# (100, 5500)

# %% [markdown]
# Defining model  with 100 Epochs

# %%
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 1096 samples, validate on 100 samples
# Epoch 1/100
# 1096/1096 [==============================] - 2s 2ms/step - loss: 0.6930 - val_loss: 0.6927
# Epoch 2/100
# 1096/1096 [==============================] - 2s 2ms/step - loss: 0.6926 - val_loss: 0.6922
# Epoch 3/100
# 1096/1096 [==============================] - 1s 895us/step - loss: 0.6920 - val_loss: 0.6915
# Epoch 4/100
# 1096/1096 [==============================] - 1s 887us/step - loss: 0.6913 - val_loss: 0.6904
# Epoch 5/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: 0.6899 - val_loss: 0.6878
# Epoch 6/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: 0.6865 - val_loss: 0.6806
# Epoch 7/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: 0.6751 - val_loss: 0.6493
# Epoch 8/100
# 1096/1096 [==============================] - 1s 908us/step - loss: 0.6153 - val_loss: 0.4470
# Epoch 9/100
# 1096/1096 [==============================] - 1s 904us/step - loss: 0.2274 - val_loss: -0.3074
# Epoch 10/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.3445 - val_loss: -0.4486
# Epoch 11/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4189 - val_loss: -0.4583
# Epoch 12/100
# 1096/1096 [==============================] - 1s 915us/step - loss: -0.4269 - val_loss: -0.4630
# Epoch 13/100
# 1096/1096 [==============================] - 2s 1ms/step - loss: -0.4302 - val_loss: -0.4631
# Epoch 14/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4313 - val_loss: -0.4644
# Epoch 15/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4323 - val_loss: -0.4617
# Epoch 16/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4330 - val_loss: -0.4665
# Epoch 17/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4344 - val_loss: -0.4700
# Epoch 18/100
# 1096/1096 [==============================] - 1s 996us/step - loss: -0.4349 - val_loss: -0.4654
# Epoch 19/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4360 - val_loss: -0.4692
# Epoch 20/100
# 1096/1096 [==============================] - 1s 927us/step - loss: -0.4364 - val_loss: -0.4703
# Epoch 21/100
# 1096/1096 [==============================] - 1s 911us/step - loss: -0.4382 - val_loss: -0.4676
# Epoch 22/100
# 1096/1096 [==============================] - 1s 944us/step - loss: -0.4369 - val_loss: -0.4705
# Epoch 23/100
# 1096/1096 [==============================] - 1s 945us/step - loss: -0.4383 - val_loss: -0.4673
# Epoch 24/100
# 1096/1096 [==============================] - 1s 922us/step - loss: -0.4377 - val_loss: -0.4730
# Epoch 25/100
# 1096/1096 [==============================] - 1s 898us/step - loss: -0.4392 - val_loss: -0.4719
# Epoch 26/100
# 1096/1096 [==============================] - 1s 913us/step - loss: -0.4389 - val_loss: -0.4713
# Epoch 27/100
# 1096/1096 [==============================] - 1s 955us/step - loss: -0.4390 - val_loss: -0.4722
# Epoch 28/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4404 - val_loss: -0.4720
# Epoch 29/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4403 - val_loss: -0.4714
# Epoch 30/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4391 - val_loss: -0.4737
# Epoch 31/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4404 - val_loss: -0.4717
# Epoch 32/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4406 - val_loss: -0.4717
# Epoch 33/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4403 - val_loss: -0.4730
# Epoch 34/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4413 - val_loss: -0.4734
# Epoch 35/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4411 - val_loss: -0.4736
# Epoch 36/100
# 1096/1096 [==============================] - 1s 990us/step - loss: -0.4414 - val_loss: -0.4735
# Epoch 37/100
# 1096/1096 [==============================] - 1s 931us/step - loss: -0.4405 - val_loss: -0.4689
# Epoch 38/100
# 1096/1096 [==============================] - 2s 1ms/step - loss: -0.4391 - val_loss: -0.4724
# Epoch 39/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4413 - val_loss: -0.4755
# Epoch 40/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4424 - val_loss: -0.4747
# Epoch 41/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4424 - val_loss: -0.4763
# Epoch 42/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4425 - val_loss: -0.4749
# Epoch 43/100
# 1096/1096 [==============================] - 1s 985us/step - loss: -0.4425 - val_loss: -0.4750
# Epoch 44/100
# 1096/1096 [==============================] - 1s 965us/step - loss: -0.4421 - val_loss: -0.4769
# Epoch 45/100
# 1096/1096 [==============================] - 1s 948us/step - loss: -0.4423 - val_loss: -0.4753
# Epoch 46/100
# 1096/1096 [==============================] - 1s 890us/step - loss: -0.4419 - val_loss: -0.4747
# Epoch 47/100
# 1096/1096 [==============================] - 1s 894us/step - loss: -0.4420 - val_loss: -0.4764
# Epoch 48/100
# 1096/1096 [==============================] - 1s 946us/step - loss: -0.4426 - val_loss: -0.4767
# Epoch 49/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4419 - val_loss: -0.4750
# Epoch 50/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4431 - val_loss: -0.4765
# Epoch 51/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4433 - val_loss: -0.4751
# Epoch 52/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4431 - val_loss: -0.4760
# Epoch 53/100
# 1096/1096 [==============================] - 2s 2ms/step - loss: -0.4433 - val_loss: -0.4753
# Epoch 54/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4435 - val_loss: -0.4762
# Epoch 55/100
# 1096/1096 [==============================] - 2s 2ms/step - loss: -0.4435 - val_loss: -0.4761
# Epoch 56/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4435 - val_loss: -0.4760
# Epoch 57/100
# 1096/1096 [==============================] - 1s 958us/step - loss: -0.4437 - val_loss: -0.4751
# Epoch 58/100
# 1096/1096 [==============================] - 1s 925us/step - loss: -0.4434 - val_loss: -0.4761
# Epoch 59/100
# 1096/1096 [==============================] - 1s 942us/step - loss: -0.4436 - val_loss: -0.4763
# Epoch 60/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4438 - val_loss: -0.4766
# Epoch 61/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4432 - val_loss: -0.4735
# Epoch 62/100
# 1096/1096 [==============================] - 1s 949us/step - loss: -0.4437 - val_loss: -0.4757
# Epoch 63/100
# 1096/1096 [==============================] - 1s 986us/step - loss: -0.4433 - val_loss: -0.4763
# Epoch 64/100
# 1096/1096 [==============================] - 1s 977us/step - loss: -0.4438 - val_loss: -0.4762
# Epoch 65/100
# 1096/1096 [==============================] - 1s 852us/step - loss: -0.4438 - val_loss: -0.4761
# Epoch 66/100
# 1096/1096 [==============================] - 1s 871us/step - loss: -0.4437 - val_loss: -0.4781
# Epoch 67/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4446 - val_loss: -0.4771
# Epoch 68/100
# 1096/1096 [==============================] - 1s 890us/step - loss: -0.4441 - val_loss: -0.4772
# Epoch 69/100
# 1096/1096 [==============================] - 1s 933us/step - loss: -0.4442 - val_loss: -0.4770
# Epoch 70/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4444 - val_loss: -0.4770
# Epoch 71/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4440 - val_loss: -0.4743
# Epoch 72/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4442 - val_loss: -0.4760
# Epoch 73/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4444 - val_loss: -0.4774
# Epoch 74/100
# 1096/1096 [==============================] - 1s 916us/step - loss: -0.4447 - val_loss: -0.4765
# Epoch 75/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4439 - val_loss: -0.4758
# Epoch 76/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4445 - val_loss: -0.4759
# Epoch 77/100
# 1096/1096 [==============================] - 1s 927us/step - loss: -0.4446 - val_loss: -0.4770
# Epoch 78/100
# 1096/1096 [==============================] - 1s 952us/step - loss: -0.4445 - val_loss: -0.4770
# Epoch 79/100
# 1096/1096 [==============================] - 1s 941us/step - loss: -0.4450 - val_loss: -0.4757
# Epoch 80/100
# 1096/1096 [==============================] - 1s 942us/step - loss: -0.4448 - val_loss: -0.4767
# Epoch 81/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4445 - val_loss: -0.4775
# Epoch 82/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4442 - val_loss: -0.4742
# Epoch 83/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4451 - val_loss: -0.4765
# Epoch 84/100
# 1096/1096 [==============================] - 2s 2ms/step - loss: -0.4447 - val_loss: -0.4767
# Epoch 85/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4446 - val_loss: -0.4762
# Epoch 86/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4450 - val_loss: -0.4755
# Epoch 87/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4448 - val_loss: -0.4770
# Epoch 88/100
# 1096/1096 [==============================] - 1s 967us/step - loss: -0.4453 - val_loss: -0.4774
# Epoch 89/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4453 - val_loss: -0.4768
# Epoch 90/100
# 1096/1096 [==============================] - 1s 969us/step - loss: -0.4449 - val_loss: -0.4774
# Epoch 91/100
# 1096/1096 [==============================] - 1s 955us/step - loss: -0.4452 - val_loss: -0.4763
# Epoch 92/100
# 1096/1096 [==============================] - 1s 949us/step - loss: -0.4450 - val_loss: -0.4744
# Epoch 93/100
# 1096/1096 [==============================] - 1s 972us/step - loss: -0.4450 - val_loss: -0.4761
# Epoch 94/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4451 - val_loss: -0.4759
# Epoch 95/100
# 1096/1096 [==============================] - 1s 983us/step - loss: -0.4453 - val_loss: -0.4775
# Epoch 96/100
# 1096/1096 [==============================] - 1s 986us/step - loss: -0.4452 - val_loss: -0.4773
# Epoch 97/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4450 - val_loss: -0.4771
# Epoch 98/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4450 - val_loss: -0.4770
# Epoch 99/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4453 - val_loss: -0.4765
# Epoch 100/100
# 1096/1096 [==============================] - 1s 1ms/step - loss: -0.4455 - val_loss: -0.4776
